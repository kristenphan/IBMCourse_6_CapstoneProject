# %% [markdown]
# <img src = "https://res.cloudinary.com/cityunscripted/image/upload/s--7t8HSmQ2--/c_fill,f_auto,g_auto:subject,h_270,q_auto,w_375/v1561714908/production/experiences/amsterdam/eat-and-drink-like-a-local-in-amsterdam/ubu2xkch5ihstkm0ruur.jpg" width = 400> </a>

# %% [markdown]
# <h1 align=center><font size = 5.5>Capstone Project: Cuisine Journey in Amsterdam with Kristen Phan</font></h1>
# <h1 align=center><font size = 4.5>Applied Data Science Capstone Course by IBM/Coursera</font></h1>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1. [Introduction](#introduction)<br>
# 2. [Data](#data)<br>
# 3. [Methodology & Analysis](#methodology) <br>
# 4. [Results & Discussion](#results) <br>
# 5. [Conclusion](#conclusion) <br>
# 6. [About the Author: Kristen Phan](#about) <br>
# </div>
# <hr>

# %% [markdown]
# ## 1. Introduction <a name="introduction"></a>

# %% [markdown]
# As a wise man once said, “Food is a central activity of mankind and one of the single most significant trademarks of a culture,”  In this notebook, I will be walking with you along the streets of Amsterdam and cherishing its culture through a new lens that sees through the power of Data Science, stomachs and hearts __(*puns intended*).__

# %% [markdown]
# This notebook is for the Applied Data Science Capstone course. The prompt is that course participants define a problem or an idea of their choice, where they would need to leverage the Foursquare location data via Foursquare API to solve or execute.

# %% [markdown]
# Course URL: https://www.coursera.org/learn/applied-data-science-capstone/

# %% [markdown]
# ## 2. Data <a name="data"></a>

# %% [markdown]
# Foursquare is a global location technology company powering location needs for various businesses including Uber and Twitter.
# <br>
# <br>
# In this project, we will obtain information about restaurants in Amsterdam through Foursquare API for analysis and visualization purposes. Details on each restaurant include: type of cuisine (e.g. Italian) and locations (i.e. longtitude and latitude), and pricing points.

# %%
# import libraries
import numpy as np
import pandas as pd
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
print('Libraries downloaded!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     altair-4.0.0               |             py_0         606 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.0.0-py_0        conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# altair-4.0.0         | 606 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries downloaded!

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails:
# client_id: YHN5CBFULARYVJSM1NIOR50MDHEKZHKNZIV4QWXMY31I1M2K
# client_secret:VCH4GRZZLOXISH3IEV34CCOX55F10LAAPQNDA0HL4VLIQCT5

# %%
# Set parameters for Foursquare API call
category = '4d4b7105d754a06374d81259' # Category ID corresponding to food estabilishments was taken from Foursquare web site (https://developer.foursquare.com/docs/resources/categories)
limit = 100
near = 'Amsterdam' # looking up restaurants in Amsterdam

# make an API call to Foursquare to retrive 100 restaurants near Amsterdam
import requests
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&near={}&categoryId={}&limit={}'.format(
        client_id, client_secret, version, near, category, limit)

results = requests.get(url).json()["response"]['groups'][0]['items']
print('Number of restaurants retrieved: '+str(len(results)))
# Out:
# Number of restaurants retrieved: 100

# %%
results
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '557ee469498e467dec98aef2',
#    'name': 'Margherita Tutta La Vita!',
#    'location': {'address': 'Dalsteindreef 54',
#     'lat': 52.329053604986505,
#     'lng': 4.955773467121892,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.329053604986505,
#       'lng': 4.955773467121892}],
#     'postalCode': '1112 XC',
#     'cc': 'NL',
#     'country': 'Nederland',
#     'formattedAddress': ['Dalsteindreef 54', '1112 XC', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-557ee469498e467dec98aef2-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '561e39f5498e059a294a7913',
#    'name': 'Toastable',
#    'location': {'address': 'Nieuwendijk 6',
#     'lat': 52.378790499454354,
#     'lng': 4.894805058602038,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.378790499454354,
#       'lng': 4.894805058602038}],
#     'postalCode': '1012 MK',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Nieuwendijk 6', '1012 MK Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c5941735',
#      'name': 'Sandwich Place',
#      'pluralName': 'Sandwich Places',
#      'shortName': 'Sandwiches',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-561e39f5498e059a294a7913-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '57eeb952498ed4d9085efa38',
#    'name': 'Nefis Houtoven',
#    'location': {'lat': 52.36241229997561,
#     'lng': 4.9261739071640775,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36241229997561,
#       'lng': 4.9261739071640775}],
#     'postalCode': '1093 GE',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['1093 GE Amsterdam', 'Nederland']},
#    'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#      'name': 'Turkish Restaurant',
#      'pluralName': 'Turkish Restaurants',
#      'shortName': 'Turkish',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-57eeb952498ed4d9085efa38-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55523531498ee5528513f68e',
#    'name': 'd&a Hummus Bistro',
#    'location': {'address': 'Westerstraat 136',
#     'lat': 52.3783524750886,
#     'lng': 4.882680512899208,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3783524750886,
#       'lng': 4.882680512899208}],
#     'postalCode': '1015 MP',
#     'cc': 'NL',
#     'neighborhood': 'Jordaan',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Westerstraat 136',
#      '1015 MP Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '52e81612bcbc57f1066b79f1',
#      'name': 'Bistro',
#      'pluralName': 'Bistros',
#      'shortName': 'Bistro',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55523531498ee5528513f68e-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '559957ce498eb48bf7428bb6',
#    'name': 'Plato Loco',
#    'location': {'address': 'Rombout Hogerbeetsstraat 29',
#     'lat': 52.37799063489079,
#     'lng': 4.874099224273423,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.37799063489079,
#       'lng': 4.874099224273423}],
#     'postalCode': '1052 VN',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Rombout Hogerbeetsstraat 29',
#      '1052 VN Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d144941735',
#      'name': 'Caribbean Restaurant',
#      'pluralName': 'Caribbean Restaurants',
#      'shortName': 'Caribbean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-559957ce498eb48bf7428bb6-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5762feca498ec7181dcd8579',
#    'name': 'The Lobby, Fizeaustraat',
#    'location': {'address': 'Fizeaustraat 2',
#     'lat': 52.34542439900525,
#     'lng': 4.925503247301483,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.34542439900525,
#       'lng': 4.925503247301483}],
#     'postalCode': '1097 SC',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Fizeaustraat 2', '1097 SC Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5762feca498ec7181dcd8579-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '54f5efa2498e33a9d04091e6',
#    'name': 'bistrot des alpes',
#    'location': {'address': 'Utrechtsedwarsstraat 141',
#     'lat': 52.36200040873267,
#     'lng': 4.901349861506372,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36200040873267,
#       'lng': 4.901349861506372}],
#     'postalCode': '1017 WE',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Utrechtsedwarsstraat 141',
#      '1017 WE Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-54f5efa2498e33a9d04091e6-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a7d0cdcf964a5206aee1fe3',
#    'name': 'Le Fournil de Sébastien',
#    'location': {'address': 'Olympiaplein 119',
#     'crossStreet': 'Stadionweg',
#     'lat': 52.346299,
#     'lng': 4.867988,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.346299,
#       'lng': 4.867988}],
#     'cc': 'NL',
#     'neighborhood': 'Stadionbuurt',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Olympiaplein 119 (Stadionweg)',
#      'Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a7d0cdcf964a5206aee1fe3-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a2bbd19f964a520db961fe3',
#    'name': 'Gartine',
#    'location': {'address': 'Taksteeg 7',
#     'crossStreet': 'Kalverstraat',
#     'lat': 52.36915717683828,
#     'lng': 4.891615198788351,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36915717683828,
#       'lng': 4.891615198788351}],
#     'postalCode': '1012 PB',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Taksteeg 7 (Kalverstraat)',
#      '1012 PB Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a2bbd19f964a520db961fe3-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b2b70bbf964a52067b624e3',
#    'name': 'Foodware',
#    'location': {'address': 'Looiersgracht 12',
#     'crossStreet': 'Prinsengracht',
#     'lat': 52.3688496,
#     'lng': 4.8819963,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3688496,
#       'lng': 4.8819963}],
#     'postalCode': '1016 VS',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Looiersgracht 12 (Prinsengracht)',
#      '1016 VS Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d146941735',
#      'name': 'Deli / Bodega',
#      'pluralName': 'Delis / Bodegas',
#      'shortName': 'Deli / Bodega',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b2b70bbf964a52067b624e3-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '56220078498e71764f94c63a',
#    'name': 'Bakers & Roasters',
#    'location': {'address': 'Kadijksplein 16',
#     'lat': 52.370462488009196,
#     'lng': 4.9127381810865485,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.370462488009196,
#       'lng': 4.9127381810865485}],
#     'postalCode': '1018 AC',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Kadijksplein 16', '1018 AC Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-56220078498e71764f94c63a-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a27db33f964a5207f921fe3',
#    'name': 'Umeno',
#    'location': {'address': 'Agamemnonstraat 27',
#     'lat': 52.344678,
#     'lng': 4.863752,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.344678,
#       'lng': 4.863752}],
#     'postalCode': '1076 LP',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Agamemnonstraat 27',
#      '1076 LP Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a27db33f964a5207f921fe3-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55674fe7498e0a4781b0f3d8',
#    'name': 'Choux',
#    'location': {'address': 'De Ruijterkade 128',
#     'lat': 52.377693060623656,
#     'lng': 4.907260213346564,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.377693060623656,
#       'lng': 4.907260213346564}],
#     'postalCode': '1011AC',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['De Ruijterkade 128',
#      '1011AC Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55674fe7498e0a4781b0f3d8-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55c10ee5498ecb81fe809f9d',
#    'name': 'Omelegg - City Centre',
#    'location': {'address': 'Nieuwebrugsteeg 24',
#     'crossStreet': 'warmoesstraat',
#     'lat': 52.37606,
#     'lng': 4.899802,
#     'labeledLatLngs': [{'label': 'display', 'lat': 52.37606, 'lng': 4.899802}],
#     'postalCode': '1012 AH',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Nieuwebrugsteeg 24 (warmoesstraat)',
#      '1012 AH Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '136396172'}},
#   'referralId': 'e-0-55c10ee5498ecb81fe809f9d-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a2703c9f964a52069851fe3',
#    'name': 'Ciel Bleu Restaurant',
#    'location': {'address': 'Hotel Okura',
#     'crossStreet': 'Ferdinand Bolstraat 333',
#     'lat': 52.3487171934699,
#     'lng': 4.893712157600433,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3487171934699,
#       'lng': 4.893712157600433}],
#     'postalCode': '1072 LH',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Hotel Okura (Ferdinand Bolstraat 333)',
#      '1072 LH Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a2703c9f964a52069851fe3-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5b749a32791871002c2e4e11',
#    'name': 'FACTORY GIRL',
#    'location': {'address': 'Saenredamstraat 32',
#     'lat': 52.3556065,
#     'lng': 4.8889255,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3556065,
#       'lng': 4.8889255}],
#     'postalCode': '1072 CH',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Saenredamstraat 32',
#      '1072 CH Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '554203177'}},
#   'referralId': 'e-0-5b749a32791871002c2e4e11-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f9e93cce4b02343ca00c6cf',
#    'name': 'Pllek',
#    'location': {'address': 'Tt. Neveritaweg 62',
#     'crossStreet': 'NDSM-werf',
#     'lat': 52.39902943389349,
#     'lng': 4.893159749439702,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.39902943389349,
#       'lng': 4.893159749439702}],
#     'postalCode': '1033 WB',
#     'cc': 'NL',
#     'neighborhood': 'Stadsdeel Noord',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Tt. Neveritaweg 62 (NDSM-werf)',
#      '1033 WB Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d155941735',
#      'name': 'Gastropub',
#      'pluralName': 'Gastropubs',
#      'shortName': 'Gastropub',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f9e93cce4b02343ca00c6cf-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a27079bf964a5205d8e1fe3',
#    'name': 'Winkel 43',
#    'location': {'address': 'Noordermarkt 43',
#     'crossStreet': 'at Westerstraat',
#     'lat': 52.37909,
#     'lng': 4.88622,
#     'labeledLatLngs': [{'label': 'display', 'lat': 52.37909, 'lng': 4.88622}],
#     'postalCode': '1015 NA',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Noordermarkt 43 (at Westerstraat)',
#      '1015 NA Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '33247208'}},
#   'referralId': 'e-0-4a27079bf964a5205d8e1fe3-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b586efef964a520855728e3',
#    'name': 'Frens Haringhandel',
#    'location': {'address': 'T/O Singel 468',
#     'lat': 52.36740416799192,
#     'lng': 4.889473260915847,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36740416799192,
#       'lng': 4.889473260915847}],
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': '1017 AW',
#     'country': 'Nederland',
#     'formattedAddress': ['T/O Singel 468', 'Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1cb941735',
#      'name': 'Food Truck',
#      'pluralName': 'Food Trucks',
#      'shortName': 'Food Truck',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b586efef964a520855728e3-18'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '512bf050e0e22f13624b5ecf',
#    'name': 'Omelegg - De Pijp',
#    'location': {'address': 'Ferdinand Bolstraat 143',
#     'lat': 52.351701507597895,
#     'lng': 4.89138584990706,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.351701507597895,
#       'lng': 4.89138584990706}],
#     'postalCode': '1072 LH',
#     'cc': 'NL',
#     'neighborhood': 'Nieuwe Pijp',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Ferdinand Bolstraat 143',
#      '1072 LH Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '49221524'}},
#   'referralId': 'e-0-512bf050e0e22f13624b5ecf-19'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51d7f23e498eb1cf17ba4447',
#    'name': 'Eetwinkel Buurman & Buurman',
#    'location': {'address': 'Mercatorstraat 171',
#     'lat': 52.375401,
#     'lng': 4.848373,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.375401,
#       'lng': 4.848373}],
#     'postalCode': '1056 RE',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Mercatorstraat 171',
#      '1056 RE Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-51d7f23e498eb1cf17ba4447-20'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5305f11f11d2d3664fb633a2',
#    'name': 'Bakhuys',
#    'location': {'address': 'Sarphatistraat 61',
#     'lat': 52.36105422036529,
#     'lng': 4.907108251136343,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36105422036529,
#       'lng': 4.907108251136343}],
#     'postalCode': '1018 EX',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Sarphatistraat 61',
#      '1018 EX Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5305f11f11d2d3664fb633a2-21'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b45ca45f964a520601026e3',
#    'name': 'Pasta di Mamma',
#    'location': {'address': 'Bijlmerplein 687-G',
#     'lat': 52.314779235934964,
#     'lng': 4.955087427591258,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.314779235934964,
#       'lng': 4.955087427591258}],
#     'postalCode': '1102 DZ',
#     'cc': 'NL',
#     'city': 'Amsterdam-Zuidoost',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Bijlmerplein 687-G',
#      '1102 DZ Amsterdam Zuidoost',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b45ca45f964a520601026e3-22'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '52ebb2ed498e9ea23f6c7096',
#    'name': 'De Ceuvel',
#    'location': {'address': 'Korte Papaverweg 4',
#     'lat': 52.39320704379589,
#     'lng': 4.910642380271526,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.39320704379589,
#       'lng': 4.910642380271526}],
#     'cc': 'NL',
#     'neighborhood': 'Stadsdeel Noord',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Korte Papaverweg 4', 'Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-52ebb2ed498e9ea23f6c7096-23'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '550c3cee498e3f22bf1c9d7f',
#    'name': 'Cafe De Wetering',
#    'location': {'address': 'Weteringstraat 37',
#     'lat': 52.36115325787267,
#     'lng': 4.888831421453769,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36115325787267,
#       'lng': 4.888831421453769}],
#     'postalCode': '1017SM',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noordholland',
#     'country': 'Nederland',
#     'formattedAddress': ['Weteringstraat 37',
#      '1017SM Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-550c3cee498e3f22bf1c9d7f-24'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '58a4850c739d851310b8b322',
#    'name': 'Local Hero',
#    'location': {'address': 'Jan van Galenstraat 92H',
#     'lat': 52.3749466679783,
#     'lng': 4.860697960902276,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3749466679783,
#       'lng': 4.860697960902276}],
#     'cc': 'NL',
#     'neighborhood': 'Stadsdeel West',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Jan van Galenstraat 92H', 'Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-58a4850c739d851310b8b322-25'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5b0fa7e212f0a9002cb223cb',
#    'name': 'Bhatti Pasal',
#    'location': {'address': 'Voetboogstraat 23',
#     'lat': 52.3680554,
#     'lng': 4.8908381,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3680554,
#       'lng': 4.8908381}],
#     'postalCode': '1012 XK',
#     'cc': 'NL',
#     'neighborhood': 'Stadsdeel Centrum',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Voetboogstraat 23',
#      '1012 XK Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5b0fa7e212f0a9002cb223cb-26'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a2703d7f964a52095851fe3',
#    'name': 'Vlaming eten & drinken',
#    'location': {'address': 'Lindengracht 95',
#     'lat': 52.380016,
#     'lng': 4.8845315,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.380016,
#       'lng': 4.8845315}],
#     'postalCode': '1015 KD',
#     'cc': 'NL',
#     'neighborhood': 'Jordaan',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Lindengracht 95', '1015 KD Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a2703d7f964a52095851fe3-27'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '54819cb3498e6ba0cc56c0e0',
#    'name': 'Kessens',
#    'location': {'address': 'Rozengracht 24',
#     'lat': 52.373800316876,
#     'lng': 4.881990847017862,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.373800316876,
#       'lng': 4.881990847017862}],
#     'postalCode': '1016 NC',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Rozengracht 24', '1016 NC Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-54819cb3498e6ba0cc56c0e0-28'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4fe4480ce4b08c839cc14ea2',
#    'name': 'The Seafood Bar',
#    'location': {'address': 'Van Baerlestraat 5',
#     'lat': 52.3599212,
#     'lng': 4.8774894,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3599212,
#       'lng': 4.8774894}],
#     'postalCode': '1071 AL',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Van Baerlestraat 5',
#      '1071 AL Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1ce941735',
#      'name': 'Seafood Restaurant',
#      'pluralName': 'Seafood Restaurants',
#      'shortName': 'Seafood',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '551884069'}},
#   'referralId': 'e-0-4fe4480ce4b08c839cc14ea2-29'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55ce5e9d498e0630e2c94dc0',
#    'name': 'Dignita Restaurant',
#    'location': {'address': 'Koninginneweg 218H',
#     'lat': 52.351773951293886,
#     'lng': 4.857267008341895,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.351773951293886,
#       'lng': 4.857267008341895}],
#     'postalCode': '1075 EL',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Koninginneweg 218H',
#      '1075 EL Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55ce5e9d498e0630e2c94dc0-30'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5914315a9ad60e49d24b5d16',
#    'name': 'The Cottage',
#    'location': {'address': 'Linnaeusstraat 88',
#     'lat': 52.35634825222423,
#     'lng': 4.927312165034022,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35634825222423,
#       'lng': 4.927312165034022}],
#     'postalCode': '1092CP',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Linnaeusstraat 88',
#      '1092CP Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a00',
#      'name': 'Comfort Food Restaurant',
#      'pluralName': 'Comfort Food Restaurants',
#      'shortName': 'Comfort Food',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5914315a9ad60e49d24b5d16-31'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c08d12bbbc676b0191847d5',
#    'name': 'Het Zaanse Bakkertje',
#    'location': {'address': 'Lagedijk 11a',
#     'lat': 52.471997563468555,
#     'lng': 4.811641906009624,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.471997563468555,
#       'lng': 4.811641906009624}],
#     'postalCode': '1544 BA',
#     'cc': 'NL',
#     'city': 'Zaandijk',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Lagedijk 11a', '1544 BA Zaandijk', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c08d12bbbc676b0191847d5-32'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5511af71498e0f789cd84af2',
#    'name': 'The Seafood Bar',
#    'location': {'address': 'Spui 15',
#     'lat': 52.36873,
#     'lng': 4.8906,
#     'labeledLatLngs': [{'label': 'display', 'lat': 52.36873, 'lng': 4.8906}],
#     'postalCode': '1012 WX',
#     'cc': 'NL',
#     'neighborhood': 'Stadsdeel Centrum',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Spui 15', '1012 WX Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1ce941735',
#      'name': 'Seafood Restaurant',
#      'pluralName': 'Seafood Restaurants',
#      'shortName': 'Seafood',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5511af71498e0f789cd84af2-33'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '514e0cbce4b0679548f4d62a',
#    'name': 'The Lobby',
#    'location': {'address': 'Nes 49',
#     'lat': 52.37115889725467,
#     'lng': 4.893661205025948,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.37115889725467,
#       'lng': 4.893661205025948}],
#     'postalCode': '1012 KD',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Nes 49', '1012 KD Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-514e0cbce4b0679548f4d62a-34'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e05ddb414959022c88c2dc9',
#    'name': 'De Bakkerswinkel',
#    'location': {'address': 'Roelof Hartstraat 68',
#     'lat': 52.352294860686975,
#     'lng': 4.8852787155145085,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.352294860686975,
#       'lng': 4.8852787155145085}],
#     'postalCode': '1071 VM',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Roelof Hartstraat 68',
#      '1071 VM Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e05ddb414959022c88c2dc9-35'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a43b1d7f964a520b0a61fe3',
#    'name': 'La Perla',
#    'location': {'address': 'Tweede Tuindwarsstraat 14 & 53',
#     'crossStreet': 'Tuinstraat',
#     'lat': 52.37701278030078,
#     'lng': 4.881970923745858,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.37701278030078,
#       'lng': 4.881970923745858}],
#     'postalCode': '1015 RZ',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Tweede Tuindwarsstraat 14 & 53 (Tuinstraat)',
#      '1015 RZ Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a43b1d7f964a520b0a61fe3-36'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '569005c2498e01f792f4a22b',
#    'name': 'Pendergast',
#    'location': {'address': 'Groen v Prinstererstraat 14',
#     'lat': 52.38485820725974,
#     'lng': 4.871349443996078,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.38485820725974,
#       'lng': 4.871349443996078}],
#     'postalCode': '1051EE',
#     'cc': 'NL',
#     'neighborhood': 'Staats',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Groen v Prinstererstraat 14',
#      '1051EE Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1df931735',
#      'name': 'BBQ Joint',
#      'pluralName': 'BBQ Joints',
#      'shortName': 'BBQ',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-569005c2498e01f792f4a22b-37'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a2703ebf964a520b7851fe3',
#    'name': 'Small World Catering',
#    'location': {'address': 'Binnen Oranjestraat 14',
#     'lat': 52.38218904227042,
#     'lng': 4.887082361755015,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.38218904227042,
#       'lng': 4.887082361755015}],
#     'postalCode': '1013 JA',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Binnen Oranjestraat 14',
#      '1013 JA Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c5941735',
#      'name': 'Sandwich Place',
#      'pluralName': 'Sandwich Places',
#      'shortName': 'Sandwiches',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a2703ebf964a520b7851fe3-38'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5a14377f28374e648ad1c6df',
#    'name': "Rudi's Original Stroopwafels",
#    'location': {'address': '180 Albert Cuypstraat',
#     'lat': 52.355897,
#     'lng': 4.895025,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.355897,
#       'lng': 4.895025}],
#     'postalCode': '1073 BM',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['180 Albert Cuypstraat',
#      '1073 BM Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '56aa371be4b08b9a8d57350b',
#      'name': 'Food Stand',
#      'pluralName': 'Food Stands',
#      'shortName': 'Food Stand',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5a14377f28374e648ad1c6df-39'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5b5ec9718c35dc002ce2dccd',
#    'name': 'PAZ Open Fire Cooking',
#    'location': {'address': 'Utrechtsestraat 128H',
#     'lat': 52.361324928310474,
#     'lng': 4.899156689643859,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.361324928310474,
#       'lng': 4.899156689643859}],
#     'postalCode': '1017VT',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Utrechtsestraat 128H',
#      '1017VT Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1cc941735',
#      'name': 'Steakhouse',
#      'pluralName': 'Steakhouses',
#      'shortName': 'Steakhouse',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '508481648'}},
#   'referralId': 'e-0-5b5ec9718c35dc002ce2dccd-40'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '53e0cca8498ed3c8aa65b287',
#    'name': 'Ashoka Restaurant -Amsterdam Centrum',
#    'location': {'address': 'Spuistraat 3G',
#     'lat': 52.37709413565575,
#     'lng': 4.894229471683502,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.37709413565575,
#       'lng': 4.894229471683502}],
#     'postalCode': '1012 SP',
#     'cc': 'NL',
#     'neighborhood': 'Stadsdeel Centrum',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Spuistraat 3G', '1012 SP Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10f941735',
#      'name': 'Indian Restaurant',
#      'pluralName': 'Indian Restaurants',
#      'shortName': 'Indian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '92167536'}},
#   'referralId': 'e-0-53e0cca8498ed3c8aa65b287-41'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5266bc5811d28dd9db0f9c1b',
#    'name': 'Restaurant Sinne',
#    'location': {'address': 'Ceintuurbaan 342',
#     'lat': 52.35316670143806,
#     'lng': 4.894051742783802,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35316670143806,
#       'lng': 4.894051742783802}],
#     'postalCode': '1072 GP',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Ceintuurbaan 342',
#      '1072 GP Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '85412845'}},
#   'referralId': 'e-0-5266bc5811d28dd9db0f9c1b-42'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a26ffc9f964a520fb801fe3',
#    'name': 'La Vallade',
#    'location': {'address': 'Ringdijk 23',
#     'lat': 52.35427040366714,
#     'lng': 4.926787448198346,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35427040366714,
#       'lng': 4.926787448198346}],
#     'postalCode': '1097 AB',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Ringdijk 23', '1097 AB Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a26ffc9f964a520fb801fe3-43'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a27080cf964a5209b8f1fe3',
#    'name': 'Levant',
#    'location': {'address': 'Weteringschans 93HS',
#     'lat': 52.360947196232885,
#     'lng': 4.887000995388796,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.360947196232885,
#       'lng': 4.887000995388796}],
#     'postalCode': '1017 RZ',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Weteringschans 93HS',
#      '1017 RZ Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#      'name': 'Turkish Restaurant',
#      'pluralName': 'Turkish Restaurants',
#      'shortName': 'Turkish',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a27080cf964a5209b8f1fe3-44'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ee4db136c25be9630ca266e',
#    'name': 'De Laatste Kruimel',
#    'location': {'address': 'Langebrugsteeg 4',
#     'lat': 52.36921970740506,
#     'lng': 4.892809970063676,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36921970740506,
#       'lng': 4.892809970063676}],
#     'postalCode': '1012 GB',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Langebrugsteeg 4',
#      '1012 GB Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ee4db136c25be9630ca266e-45'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '550872ba498eac4a3ae36400',
#    'name': 'Dikke Graaf',
#    'location': {'address': 'Wilhelminastraat 153',
# ...
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50058964e4b07a0720575441-84'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '584367295da8f471f28f4fb2',
#    'name': 'Cafe Caron',
#    'location': {'address': 'Frans Halsstraat 28h',
#     'lat': 52.357442594062086,
#     'lng': 4.888850122594896,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.357442594062086,
#       'lng': 4.888850122594896}],
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Frans Halsstraat 28h', 'Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-584367295da8f471f28f4fb2-85'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a2707c4f964a520c28e1fe3',
#    'name': 'Orontes',
#    'location': {'address': 'Albert Cuypstraat 40HS',
#     'lat': 52.35467644712307,
#     'lng': 4.888620103069332,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35467644712307,
#       'lng': 4.888620103069332}],
#     'postalCode': '1072 CV',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Albert Cuypstraat 40HS',
#      '1072 CV Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c0941735',
#      'name': 'Mediterranean Restaurant',
#      'pluralName': 'Mediterranean Restaurants',
#      'shortName': 'Mediterranean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a2707c4f964a520c28e1fe3-86'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b599470f964a520698d28e3',
#    'name': 'Vermeer',
#    'location': {'address': 'Prins Hendrikkade 59-72',
#     'crossStreet': 'corner Zeedijk',
#     'lat': 52.376668800320914,
#     'lng': 4.90045354006153,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.376668800320914,
#       'lng': 4.90045354006153}],
#     'postalCode': '1012 AD',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Prins Hendrikkade 59-72 (corner Zeedijk)',
#      '1012 AD Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b599470f964a520698d28e3-87'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '537cdbcc498e976c85be52a5',
#    'name': 'Pho 91',
#    'location': {'address': 'Albert Cuypstraat 91',
#     'lat': 52.35517807185446,
#     'lng': 4.891184968964705,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35517807185446,
#       'lng': 4.891184968964705}],
#     'postalCode': '1072 CP',
#     'cc': 'NL',
#     'neighborhood': 'Oude Pijp',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Albert Cuypstraat 91',
#      '1072 CP Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-537cdbcc498e976c85be52a5-88'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '56195619498e8c61daae7a67',
#    'name': 'Brasserie Ambassade',
#    'location': {'address': 'Herengracht 339',
#     'lat': 52.369288,
#     'lng': 4.887159,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.369288,
#       'lng': 4.887159}],
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Herengracht 339', 'Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-56195619498e8c61daae7a67-89'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a26ffcff964a5201f811fe3',
#    'name': 'Moeders',
#    'location': {'address': 'Rozengracht 251 HS',
#     'lat': 52.3718154,
#     'lng': 4.8749855,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3718154,
#       'lng': 4.8749855}],
#     'postalCode': '1016 SX',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Rozengracht 251 HS',
#      '1016 SX Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '5744ccdfe4b0c0459246b4d0',
#      'name': 'Dutch Restaurant',
#      'pluralName': 'Dutch Restaurants',
#      'shortName': 'Dutch',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a26ffcff964a5201f811fe3-90'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f896e30a17c575ae00f8546',
#    'name': 'Little Collins',
#    'location': {'address': '1e Sweelinckstraat 19-F',
#     'crossStreet': 'Sarphatipark',
#     'lat': 52.35584250396916,
#     'lng': 4.897892648357578,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35584250396916,
#       'lng': 4.897892648357578}],
#     'postalCode': '1073 CL',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['1e Sweelinckstraat 19-F (Sarphatipark)',
#      '1073 CL Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f896e30a17c575ae00f8546-91'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f575b227b0cb98b6e1e1614',
#    'name': 'BAK restaurant',
#    'location': {'address': 'Van Diemenstraat 410',
#     'lat': 52.390432142576856,
#     'lng': 4.887080047229397,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.390432142576856,
#       'lng': 4.887080047229397}],
#     'postalCode': '1013 CR',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Van Diemenstraat 410',
#      '1013 CR Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f575b227b0cb98b6e1e1614-92'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '554d32ea498e71de5dfe3dd4',
#    'name': 'Salmuera',
#    'location': {'address': 'Rozengracht 106',
#     'lat': 52.37326093062148,
#     'lng': 4.879471931545098,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.37326093062148,
#       'lng': 4.879471931545098}],
#     'postalCode': '1016 NH',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Rozengracht 106', '1016 NH Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d1be941735',
#      'name': 'Latin American Restaurant',
#      'pluralName': 'Latin American Restaurants',
#      'shortName': 'Latin American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-554d32ea498e71de5dfe3dd4-93'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '544bfab4498e954e9483a4d6',
#    'name': 'Sir Hummus',
#    'location': {'address': 'Van der Helstplein 2',
#     'lat': 52.35177452582039,
#     'lng': 4.894376993179321,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35177452582039,
#       'lng': 4.894376993179321}],
#     'postalCode': '1072 PH',
#     'cc': 'NL',
#     'neighborhood': 'Nieuwe Pijp',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Van der Helstplein 2',
#      '1072 PH Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d115941735',
#      'name': 'Middle Eastern Restaurant',
#      'pluralName': 'Middle Eastern Restaurants',
#      'shortName': 'Middle Eastern',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-544bfab4498e954e9483a4d6-94'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a27078af964a520318e1fe3',
#    'name': 'Roopram Roti',
#    'location': {'address': 'Eerste van Swindenstraat 4',
#     'lat': 52.36205212067869,
#     'lng': 4.924597021080056,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.36205212067869,
#       'lng': 4.924597021080056}],
#     'postalCode': '1093 GC',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Eerste van Swindenstraat 4',
#      '1093 GC Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d144941735',
#      'name': 'Caribbean Restaurant',
#      'pluralName': 'Caribbean Restaurants',
#      'shortName': 'Caribbean',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a27078af964a520318e1fe3-95'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '587a7a264745864e1c42824e',
#    'name': 'Tulsi Indian Restaurant',
#    'location': {'address': 'Van Woustraat 212',
#     'lat': 52.350698244655426,
#     'lng': 4.903552357356812,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.350698244655426,
#       'lng': 4.903552357356812}],
#     'postalCode': '1073NA',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Van Woustraat 212',
#      '1073NA Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d10f941735',
#      'name': 'Indian Restaurant',
#      'pluralName': 'Indian Restaurants',
#      'shortName': 'Indian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '392931356'}},
#   'referralId': 'e-0-587a7a264745864e1c42824e-96'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '57910d45498eeaf3c1c08128',
#    'name': 'Cannibale Royale',
#    'location': {'address': 'Lange Niezel 15',
#     'lat': 52.37503133828516,
#     'lng': 4.898690115430672,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.37503133828516,
#       'lng': 4.898690115430672}],
#     'postalCode': '1012 GS',
#     'cc': 'NL',
#     'neighborhood': 'De Wallen',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Lange Niezel 15', '1012 GS Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16c941735',
#      'name': 'Burger Joint',
#      'pluralName': 'Burger Joints',
#      'shortName': 'Burgers',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-57910d45498eeaf3c1c08128-97'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c2750e8905a0f47f6a76460',
#    'name': 'De Vergulden Eenhoorn',
#    'location': {'address': 'Ringdijk 58',
#     'lat': 52.35108327763757,
#     'lng': 4.9207258485327765,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.35108327763757,
#       'lng': 4.9207258485327765}],
#     'postalCode': '1097 AH',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Ringdijk 58', '1097 AH Amsterdam', 'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c2750e8905a0f47f6a76460-98'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '570fcdc6498ef98443eb7498',
#    'name': 'Onigiri Ya!',
#    'location': {'address': 'Ferdinand Bolstraat 37',
#     'lat': 52.3555453527531,
#     'lng': 4.890466091745714,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 52.3555453527531,
#       'lng': 4.890466091745714}],
#     'postalCode': '1072 LB',
#     'cc': 'NL',
#     'city': 'Amsterdam',
#     'state': 'Noord-Holland',
#     'country': 'Nederland',
#     'formattedAddress': ['Ferdinand Bolstraat 37',
#      '1072 LB Amsterdam',
#      'Nederland']},
#    'categories': [{'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-570fcdc6498ef98443eb7498-99'}]

# %%
# create a new dataframe to store venue info
venues_list = []

# return only relevant information for each nearby venue
venues_list.append([( 
            v['venue']['name'],
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
nearby_venues.columns = [
                  'venue', 
                  'id',
                  'latitude', 
                  'longitude', 
                  'category']
nearby_venues.head()
# Out:
#                        venue                        id   latitude  longitude  \
# 0  Margherita Tutta La Vita!  557ee469498e467dec98aef2  52.329054   4.955773
# 1                  Toastable  561e39f5498e059a294a7913  52.378790   4.894805
# 2             Nefis Houtoven  57eeb952498ed4d9085efa38  52.362412   4.926174
# 3          d&a Hummus Bistro  55523531498ee5528513f68e  52.378352   4.882681
# 4                 Plato Loco  559957ce498eb48bf7428bb6  52.377991   4.874099
#
#                category
# 0           Pizza Place
# 1        Sandwich Place
# 2    Turkish Restaurant
# 3                Bistro
# 4  Caribbean Restaurant

# %%
# get an array of unique venue category from nearby_venues dataframe
nearby_venues['category'].unique()
# Out:
# array(['Pizza Place', 'Sandwich Place', 'Turkish Restaurant', 'Bistro',
#        'Caribbean Restaurant', 'French Restaurant', 'Bakery',
#        'Breakfast Spot', 'Deli / Bodega', 'Japanese Restaurant',
#        'Restaurant', 'Gastropub', 'Café', 'Food Truck',
#        'Italian Restaurant', 'Seafood Restaurant',
#        'Comfort Food Restaurant', 'BBQ Joint', 'Food Stand', 'Steakhouse',
#        'Indian Restaurant', 'Vegetarian / Vegan Restaurant',
#        'Burger Joint', 'Mexican Restaurant', 'Lebanese Restaurant',
#        'Ethiopian Restaurant', 'Food Court', 'Falafel Restaurant',
#        'Middle Eastern Restaurant', 'Indonesian Restaurant',
#        'Snack Place', 'Thai Restaurant', 'South American Restaurant',
#        'Mediterranean Restaurant', 'Vietnamese Restaurant',
#        'Dutch Restaurant', 'Latin American Restaurant'], dtype=object)

# %%
# create a copy of the nearby_venues dataframe
venues_ethnic = nearby_venues.copy()

# based on the API call results, create a list of generic restaurant category that indicates generic food, not ethic food. These restaurants will be removed from the data frame as the intent is to examine the diversity in ethnic cuisine in Amsterdam as a proxy for the city's diversity in culture 
generic_category = ['Pizza Place', 'Sandwich Place', 'Bakery', 'Breakfast Spot', 'Deli / Bodega', 'Restaurant', 'Food Truck', 'Bistro', 'Gastropub', 'Seafood Restaurant', 'Café', 'Comfort Food Restaurant', 'BBQ Joint', 'Food Stand', 'Food Court', 'Burger Joint', 'Steakhouse', 'Vegetarian / Vegan Restaurant', 'Snack Place']

x = 0 # intialize counter x

for i in range(venues_ethnic.shape[0]):
    if venues_ethnic.loc[i,'category'] in generic_category:
        venues_ethnic = venues_ethnic.drop([i])
        x = x + 1 # increment counter x
    

venues_ethnic = venues_ethnic.reset_index(drop=True)
print('Number of generic restaurants removed from the list: ', x)
print('Number of ethic restaurants remaining on the list: ', venues_ethnic.shape[0])

# the result only contains restaurants which serve ethinic food
venues_ethnic['category'].unique()
# Out:
# Number of generic restaurants removed from the list:  61
# Number of ethic restaurants remaining on the list:  39
# array(['Turkish Restaurant', 'Caribbean Restaurant', 'French Restaurant',
#        'Japanese Restaurant', 'Italian Restaurant', 'Indian Restaurant',
#        'Mexican Restaurant', 'Lebanese Restaurant',
#        'Ethiopian Restaurant', 'Falafel Restaurant',
#        'Middle Eastern Restaurant', 'Indonesian Restaurant',
#        'Thai Restaurant', 'South American Restaurant',
#        'Mediterranean Restaurant', 'Vietnamese Restaurant',
#        'Dutch Restaurant', 'Latin American Restaurant'], dtype=object)

# %%
# display basic info about the final version of venues_ethic dataframe containing restaurants serving ethnic food
venues_ethnic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
# venue        39 non-null object
# id           39 non-null object
# latitude     39 non-null float64
# longitude    39 non-null float64
# category     39 non-null object
# dtypes: float64(2), object(3)
# memory usage: 1.6+ KB

# %%
venues_ethnic.head()
# Out:
#                      venue                        id   latitude  longitude  \
# 0           Nefis Houtoven  57eeb952498ed4d9085efa38  52.362412   4.926174
# 1               Plato Loco  559957ce498eb48bf7428bb6  52.377991   4.874099
# 2  The Lobby, Fizeaustraat  5762feca498ec7181dcd8579  52.345424   4.925503
# 3        bistrot des alpes  54f5efa2498e33a9d04091e6  52.362000   4.901350
# 4                    Umeno  4a27db33f964a5207f921fe3  52.344678   4.863752
#
#                category
# 0    Turkish Restaurant
# 1  Caribbean Restaurant
# 2     French Restaurant
# 3     French Restaurant
# 4   Japanese Restaurant

# %% [markdown]
# ## 2. Methodology & Analysis <a name="methodology"></a>

# %% [markdown]
# After collecting data in the previous step, we will execute the following steps to process and analyze the collected data.

# %% [markdown]
# ### Step 1: Create Amsterdam map and superimpose the locations of restaurants onto the map

# %%
# store the latitude and longitude of Amsterdam in variables
ams_latitude = 52.370216
ams_longitude = 4.895168

# create map and display it
ams_map = folium.Map(location=[ams_latitude, ams_longitude], zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
restaurants = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(venues_ethnic.latitude, venues_ethnic.longitude):
    restaurants.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(venues_ethnic.latitude)
longitudes = list(venues_ethnic.longitude)
labels = list(venues_ethnic.category)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(ams_map)    
    
# add incidents to map
ams_map.add_child(restaurants)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create a new column 'price' to store pricing value for each restaurant
venues_ethnic['price'] = 'NA'
venues_ethnic.head()
# Out:
#                      venue                        id   latitude  longitude  \
# 0           Nefis Houtoven  57eeb952498ed4d9085efa38  52.362412   4.926174
# 1               Plato Loco  559957ce498eb48bf7428bb6  52.377991   4.874099
# 2  The Lobby, Fizeaustraat  5762feca498ec7181dcd8579  52.345424   4.925503
# 3        bistrot des alpes  54f5efa2498e33a9d04091e6  52.362000   4.901350
# 4                    Umeno  4a27db33f964a5207f921fe3  52.344678   4.863752
#
#                category price
# 0    Turkish Restaurant    NA
# 1  Caribbean Restaurant    NA
# 2     French Restaurant    NA
# 3     French Restaurant    NA
# 4   Japanese Restaurant    NA

# %%
WAIT UNTIL NEXT DAY TO RUN PREMIUM API CALLS

# make an API call to Foursquare to obtain pricing points for filtered French restaurants
for i in range(venues_ethnic.shape[0]):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venues_ethnic.loc[i, 'id'], client_id, client_secret, version)
    results = requests.get(url).json()
    venues_ethnic.loc[i, 'price'] = results['response']['venue']['price']['message']

venues_ethnic
# Out:
# {'meta': {'code': 429,
#   'errorType': 'quota_exceeded',
#   'errorDetail': 'Quota exceeded',
#   'requestId': '5e19cd3a882fc7001b7394e7'},
#  'response': {}}

# %% [markdown]
# ## 4. Results & Discussion <a name="results"></a>

# %% [markdown]
# From the above analysis, we come to the following observations:

# %% [markdown]
# - Amsterdam has a vibrant, diverse cuisine culture with 18 distict cuision options
# - As the map indicates, the majority of ethnic restaurants are located in the Centrum neighborhood
# - French cuisine seems to be the most well-loved, followed by Italian and Japanese
# - Added to the final venues_ethnic dataframe is pricing references for your convenience
# - If you ever feel like treating yourself to a fancy, French dinner, ... is your destination!

# %% [markdown]
# ## 5. Conclusion <a name="conclusion"></a>

# %% [markdown]
# It was an absolute pleasure to walk with you along the streets of Amsterdam exploring its cuisine culture! Foursquare API coupled with Folium geospatial data visualization package is such a fun way to experience new cities through the power of Data Science. So, what city would you like to visit next? :)

# %% [markdown]
# ## 6. About the Author: Kristen Phan <a name="about"></a>

# %% [markdown]
# Kristen is passionate about Consulting and Famine Alleviation, both through the means of Data Science. In her free time, she enjoys reading, going on spontaneous road trips/ backpacking trips, and spending time with family.
# <div style="direction:rtl">
#     <a href="https://www.linkedin.com/in/kristenphan/">Connect with Kristen on Linkedin</a>
# </div>
